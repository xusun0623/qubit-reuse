# %%
from draw import plot_algorithm_comparison

def draw_mrp_cp():
    mrp_cp_ratio = [10, 20, 30, 40, 50]
    mrp_cp_data = {
        "QR-MAP": [141, 281, 421, 561, 701],
        "QR-MOVE": [56, 103, 180, 194, 255],
    }
    # 调用封装函数
    plot_algorithm_comparison(
        x_values=mrp_cp_ratio,
        y_data=mrp_cp_data,
        output_file="MRP_CP_vs_depth",
        visual_type="line"
    )

draw_mrp_cp()
