# %%
from draw import plot_algorithm_comparison


def draw_bv():
    # 数据定义
    qubit_num = [10, 20, 30, 40, 50]
    qaoa_data = {"QR-MAP": [41, 91, 141, 191, 232], "QR-MOVE": [22, 35, 55, 73, 96]}

    # 调用封装函数
    plot_algorithm_comparison(
        x_values=qubit_num,
        y_data=qaoa_data,
        output_file="BV_num_vs_time",
    )


def draw_qaoa():
    qubit_num = [10, 20, 30, 40, 50]
    qaoa_data = {
        "QR-MAP": [88, 196, 202, 346, 421],
        "QR-MOVE": [79, 118, 145, 190, 298],
    }
    # 调用封装函数
    plot_algorithm_comparison(
        x_values=qubit_num,
        y_data=qaoa_data,
        output_file="QAOA_num_vs_time",
    )


def draw_mul():
    qubit_num = [10, 20, 30, 40, 50]
    mul_data = {
        "QR-MAP": [101, 221, 341, 461, 581],
        "QR-MOVE": [65, 165, 277, 397, 525],
    }
    # 调用封装函数
    plot_algorithm_comparison(
        x_values=qubit_num,
        y_data=mul_data,
        output_file="MUL_num_vs_time",
    )


def draw_rd():
    qubit_num = [10, 20, 30, 40, 50]
    rd_data = {
        "QR-MAP": [49, 100, 169, 202, 253],
        "QR-MOVE": [37, 46, 100, 121, 175],
    }
    # 调用封装函数
    plot_algorithm_comparison(
        x_values=qubit_num,
        y_data=rd_data,
        output_file="RD_num_vs_time",
    )


draw_bv()
draw_qaoa()
draw_mul()
draw_rd()
