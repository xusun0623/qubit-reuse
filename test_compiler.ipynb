# %%
from qiskit import QuantumCircuit, qasm3
from quantum_chip import QuantumChip
from hardware import HardwareParams
from qrmove_compiler import QRMoveCompiler
from utils import get_quantum_circuit

_type = "bv"
_qubit_num = 10 # 395行 * 100列

quantum_circuit: QuantumCircuit = get_quantum_circuit(_type, _qubit_num)

# quantum_circuit.draw(output="mpl", filename="./output/qaoa_10.png")
quantum_chip = QuantumChip(
    # square / hexagon / heavy_square / heavy_hexagon
    "square",
    50,
)
# quantum_chip.visualize()
hardware_param = HardwareParams(
    time_1q=50.0,  # 单比特门时间
    time_2q=300.0,  # 双比特门时间
    time_meas=4000.0,  # 测量时间
    time_reset=1000.0,  # 重置时间
)
qmc = QRMoveCompiler(
    quantum_circuit,
    quantum_chip,
    hardware_param,
)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 25
#      18 # quantum_chip.visualize()
#      19 hardware_param = HardwareParams(
#      20     time_1q=50.0,  # 单比特门时间
#      21     time_2q=300.0,  # 双比特门时间
#      22     time_meas=4000.0,  # 测量时间
#      23     time_reset=1000.0,  # 重置时间
#      24 )
# ---> 25 qmc = QRMoveCompiler(
#      26     quantum_circuit,
#      27     quantum_chip,
#      28     hardware_param,
#      29 )
#
# File /home/Quantum/Desktop/xs/time-aware-qubit-reuse/qrmove_compiler.py:31, in QRMoveCompiler.__init__(self, quantum_circuit, quantum_chip, hardware_params)
#      27 self.hardware_params: HardwareParams = hardware_params
#      28 self.circuit_matrix: QRMoveMatrix = QRMoveMatrix(
#      29     quantum_circuit, quantum_chip, hardware_params
#      30 )
# ---> 31 self.compile_program()
#
# File /home/Quantum/Desktop/xs/time-aware-qubit-reuse/qrmove_compiler.py:35, in QRMoveCompiler.compile_program(self)
#      33 def compile_program(self):
#      34     # 编译程序，三阶段优化
# ---> 35     self.pull_to_min_width()  # Stage 1：拆分并组合电路、拉取以最小化电路宽度
#      36     self.eliminate_idle_period()  # Stage 2：消除气泡
#      37     self.compress_depth_with_extra_qubit()
#
# File /home/Quantum/Desktop/xs/time-aware-qubit-reuse/qrmove_compiler.py:77, in QRMoveCompiler.pull_to_min_width(self)
#      72 ij_gid = matrix.matrix[i, j].gate_id
#      73 ij_logic_id = matrix.matrix[i, j].logic_qubit_id
#      74 if (
#      75     ij_gid != 0
#      76     and j != pivot_idx
# ---> 77     and (j_logic_id not in pulled_logic_qid)
#      78 ):
#      79     pulled_logic_qid.append(ij_logic_id)
#      80     matrix.try_pull_block(j, ij_logic_id, pivot_idx)
#
# NameError: name 'j_logic_id' is not defined
