# %%
from utils import CircuitGenerator

# %%
for i in range(10, 100, 10):
    qcm = CircuitGenerator(i)
    qcm.generateAll()
# for i in range(100, 2000, 100):
#     qcm = CircuitGenerator(i)
#     qcm.generateAll()
